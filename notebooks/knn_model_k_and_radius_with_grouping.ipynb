# %%
# Change directory to VSCode workspace root so that relative path loads work correctly. Turn this addition off with the DataScience.changeDirOnImportExport setting
# ms-python.python added
import os
try:
	os.chdir(os.path.join(os.getcwd(), '..'))
	print(os.getcwd())
except:
	pass

# %%
import os

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
from IPython.core.interactiveshell import InteractiveShell
from sklearn.base import BaseEstimator
from sklearn.metrics import make_scorer
from sklearn.model_selection import KFold, cross_val_score
from sklearn.neighbors import KNeighborsRegressor

from src.models.scoring import distance75

# Setting styles
InteractiveShell.ast_node_interactivity = "all"
sns.set(style="whitegrid", color_codes=True, rc={"figure.figsize": (12.7, 9.27)})

random_state = 123

# %%
df = pd.read_csv(os.path.join("data", "processed", "train.csv"))
df = df.drop(columns=["train"])

df_valid = pd.read_csv(os.path.join("data", "processed", "test.csv"))
df_valid = df_valid.drop(columns=["train", "spaceid", "relativeposition"])

# %%
# this drops the amount of datapoints by 95 %
df = df.groupby(
    ["buildingid", "floor", "spaceid", "relativeposition"], as_index=False
).mean()

df.drop(columns=["spaceid", "relativeposition"], inplace=True)

# %%
X = df.drop(columns=["longitude", "latitude", "floor", "buildingid"])
y = pd.DataFrame(
    {
        "lon": df.longitude,
        "lat": df.latitude,
        "floor": df.floor,
        "building": df.buildingid,
    }
)

X_valid = df_valid.drop(columns=["longitude", "latitude", "floor", "buildingid"])
y_valid = pd.DataFrame(
    {
        "lon": df_valid.longitude,
        "lat": df_valid.latitude,
        "floor": df_valid.floor,
        "building": df_valid.buildingid,
    }
)

# %%
def _get_weights(dist, weights):
    """Get the weights from an array of distances and a parameter ``weights``

    Parameters
    ----------
    dist : ndarray
        The input distances
    weights : {'uniform', 'distance' or a callable}
        The kind of weighting used

    Returns
    -------
    weights_arr : array of the same shape as ``dist``
        if ``weights == 'uniform'``, then returns None
    """
    if weights in (None, "uniform"):
        return None
    elif weights == "distance":
        # if user attempts to classify a point that was zero distance from one
        # or more training points, those training points are weighted as 1.0
        # and the other points as 0.0
        if dist.dtype is np.dtype(object):
            for point_dist_i, point_dist in enumerate(dist):
                # check if point_dist is iterable
                # (ex: RadiusNeighborClassifier.predict may set an element of
                # dist to 1e-6 to represent an 'outlier')
                if hasattr(point_dist, "__contains__") and 0.0 in point_dist:
                    dist[point_dist_i] = point_dist == 0.0
                else:
                    dist[point_dist_i] = 1.0 / point_dist
        else:
            with np.errstate(divide="ignore"):
                dist = 1.0 / dist
            inf_mask = np.isinf(dist)
            inf_row = np.any(inf_mask, axis=1)
            dist[inf_row] = inf_mask[inf_row]
        return dist
    elif callable(weights):
        return weights(dist)
    else:
        raise ValueError(
            "weights not recognized: should be 'uniform', "
            "'distance', or a callable function"
        )


class kradius(BaseEstimator):
    def __init__(
        self, metric="euclidean", weights="uniform", n_neighbors=3, radius=1.0, n_jobs=1
    ):
        self.radius = radius
        self.metric = metric
        self.weights = weights
        self.n_neighbors = n_neighbors
        self.n_jobs = n_jobs

    def fit(self, X, y):
        self.knn_model = KNeighborsRegressor(
            n_neighbors=self.n_neighbors,
            n_jobs=self.n_jobs,
            weights=self.weights,
            metric=self.metric,
        )
        self.knn_model.fit(X, y)
        return self

    def predict(self, X):

        # no need to to distance filtering if we take only 1 neighbor
        if self.n_neighbors > 1:

            _y = self.knn_model._y

            dists, inds = self.knn_model.kneighbors(X, n_neighbors=self.n_neighbors)
            # dropping value where distance too big
            # we always keep the closest point (first value)
            inds = [
                np.array(
                    [
                        index
                        for distance, index in zip(dist, ind)
                        if distance <= self.radius or distance == dist[0]
                    ]
                )
                for dist, ind in zip(dists, inds)
            ]
            dists = [
                np.array(
                    [
                        distance
                        for distance in dist
                        if distance <= self.radius or distance == dist[0]
                    ]
                )
                for dist in dists
            ]

            weights = _get_weights(dists, self.weights)

            empty_obs = np.full_like(_y[0], np.nan)

            if weights is None:
                y_pred = np.array(
                    [
                        np.mean(_y[ind, :], axis=0) if len(ind) else empty_obs
                        for (i, ind) in enumerate(inds)
                    ]
                )

            else:
                y_pred = np.array(
                    [
                        np.average(_y[ind, :], axis=0, weights=weights[i])
                        if len(ind)
                        else empty_obs
                        for (i, ind) in enumerate(inds)
                    ]
                )

            return y_pred

        else:
            return self.knn_model.predict(X)

# %%
def calculate_distance(y, y_pred):
    distance = distance75(y, y_pred)
    return np.mean(distance)


distance_scorer = make_scorer(calculate_distance, greater_is_better=False)


def squared_distance(weights):
    # replacing zero values with machine epsilon
    weights[weights == 0] = np.finfo(float).eps
    weights = [
        (1 / weights_obs ** 2) / np.sum(1 / weights_obs ** 2) for weights_obs in weights
    ]
    return weights


metric_opt = ["euclidean", "manhattan"]
weights_opt = ["uniform"]
n_neighbors_opt = range(1, 6)
radius_opt = np.arange(120, 200, step=1)

best_score = None
for metric in metric_opt:
    for weights in weights_opt:
        for n_neighbors in n_neighbors_opt:
            # no need to check for are if just one k
            if n_neighbors == 1:
                radius_opt_modified = [1]
            else:
                radius_opt_modified = radius_opt.copy()

            for radius in radius_opt_modified:
                kradius_model = kradius(
                    metric=metric,
                    weights=weights,
                    n_neighbors=n_neighbors,
                    radius=radius,
                    n_jobs=1,
                )
                folds = KFold(n_splits=10, shuffle=True, random_state=random_state)
                cv_val_scores = cross_val_score(
                    kradius_model,
                    X=X,
                    y=y,
                    scoring=distance_scorer,
                    cv=folds,
                    n_jobs=-2,
                )
                score = -cv_val_scores.mean()
                print()
                print(
                    f"metric: {metric},",
                    f"weights: {weights},",
                    f"n_neighbors: {n_neighbors},",
                    f"radius: {radius},",
                    f"score: {score}",
                )
                if best_score is None or best_score > score:
                    print("new best score found!")
                    best_score = score
                    best_params = {
                        "metric": metric,
                        "weights": weights,
                        "n_neighbors": n_neighbors,
                        "radius": radius,
                    }


print(best_params)
# Out:
# ic: manhattan, weights: uniform, n_neighbors: 3, radius: 143, score: 10.044649740259846
#
# metric: manhattan, weights: uniform, n_neighbors: 3, radius: 144, score: 10.028502960647158
#
# metric: manhattan, weights: uniform, n_neighbors: 3, radius: 145, score: 9.870508254552071
#
# metric: manhattan, weights: uniform, n_neighbors: 3, radius: 146, score: 9.871696772440654
#
# metric: manhattan, weights: uniform, n_neighbors: 3, radius: 147, score: 9.885674462703225
#
# metric: manhattan, weights: uniform, n_neighbors: 3, radius: 148, score: 9.880949962228367
#
# metric: manhattan, weights: uniform, n_neighbors: 3, radius: 149, score: 9.880949962228367
#
# metric: manhattan, weights: uniform, n_neighbors: 3, radius: 150, score: 9.895285890226992
#
# metric: manhattan, weights: uniform, n_neighbors: 3, radius: 151, score: 9.904299293062511
#
# metric: manhattan, weights: uniform, n_neighbors: 3, radius: 152, score: 9.876808417920476
#
# metric: manhattan, weights: uniform, n_neighbors: 3, radius: 153, score: 9.851888410001603
#
# metric: manhattan, weights: uniform, n_neighbors: 3, radius: 154, score: 9.854728116962203
#
# metric: manhattan, weights: uniform, n_neighbors: 3, radius: 155, score: 9.848889624061064
#
# metric: manhattan, weights: uniform, n_neighbors: 3, radius: 156, score: 9.863447348046996
#
# metric: manhattan, weights: uniform, n_neighbors: 3, radius: 157, score: 9.84726472594834
#
# metric: manhattan, weights: uniform, n_neighbors: 3, radius: 158, score: 9.859615659410565
#
# metric: manhattan, weights: uniform, n_neighbors: 3, radius: 159, score: 9.831340637243894
#
# metric: manhattan, weights: uniform, n_neighbors: 3, radius: 160, score: 9.836118736509572
#
# metric: manhattan, weights: uniform, n_neighbors: 3, radius: 161, score: 9.842840181191225
#
# metric: manhattan, weights: uniform, n_neighbors: 3, radius: 162, score: 9.850927165740114
#
# metric: manhattan, weights: uniform, n_neighbors: 3, radius: 163, score: 9.838134938421186
#
# metric: manhattan, weights: uniform, n_neighbors: 3, radius: 164, score: 9.834577535741175
#
# metric: manhattan, weights: uniform, n_neighbors: 3, radius: 165, score: 9.823855314118683
#
# metric: manhattan, weights: uniform, n_neighbors: 3, radius: 166, score: 9.840163709697636
#
# metric: manhattan, weights: uniform, n_neighbors: 3, radius: 167, score: 9.832513142527842
#
# metric: manhattan, weights: uniform, n_neighbors: 3, radius: 168, score: 9.824912468340617
#
# metric: manhattan, weights: uniform, n_neighbors: 3, radius: 169, score: 9.813044053078604
#
# metric: manhattan, weights: uniform, n_neighbors: 3, radius: 170, score: 9.823268788651939
#
# metric: manhattan, weights: uniform, n_neighbors: 3, radius: 171, score: 9.8338194496129
#
# metric: manhattan, weights: uniform, n_neighbors: 3, radius: 172, score: 9.857798009007826
#
# metric: manhattan, weights: uniform, n_neighbors: 3, radius: 173, score: 9.860419415331073
#
# metric: manhattan, weights: uniform, n_neighbors: 3, radius: 174, score: 9.832248135262187
#
# metric: manhattan, weights: uniform, n_neighbors: 3, radius: 175, score: 9.840541024158728
#
# metric: manhattan, weights: uniform, n_neighbors: 3, radius: 176, score: 9.84337029562661
#
# metric: manhattan, weights: uniform, n_neighbors: 3, radius: 177, score: 9.780849362964592
#
# metric: manhattan, weights: uniform, n_neighbors: 3, radius: 178, score: 9.762147380961382
#
# metric: manhattan, weights: uniform, n_neighbors: 3, radius: 179, score: 9.73694781982953
#
# metric: manhattan, weights: uniform, n_neighbors: 3, radius: 180, score: 9.73440903757566
#
# metric: manhattan, weights: uniform, n_neighbors: 3, radius: 181, score: 9.729069368711404
#
# metric: manhattan, weights: uniform, n_neighbors: 3, radius: 182, score: 9.69566934319441
#
# metric: manhattan, weights: uniform, n_neighbors: 3, radius: 183, score: 9.691915131778213
#
# metric: manhattan, weights: uniform, n_neighbors: 3, radius: 184, score: 9.686257897328867
#
# metric: manhattan, weights: uniform, n_neighbors: 3, radius: 185, score: 9.65906382066672
#
# metric: manhattan, weights: uniform, n_neighbors: 3, radius: 186, score: 9.650137463358224
#
# metric: manhattan, weights: uniform, n_neighbors: 3, radius: 187, score: 9.638104547463119
#
# metric: manhattan, weights: uniform, n_neighbors: 3, radius: 188, score: 9.604690566676194
#
# metric: manhattan, weights: uniform, n_neighbors: 3, radius: 189, score: 9.59932065772957
#
# metric: manhattan, weights: uniform, n_neighbors: 3, radius: 190, score: 9.594371758879184
#
# metric: manhattan, weights: uniform, n_neighbors: 3, radius: 191, score: 9.632495345812066
#
# metric: manhattan, weights: uniform, n_neighbors: 3, radius: 192, score: 9.560055894147393
#
# metric: manhattan, weights: uniform, n_neighbors: 3, radius: 193, score: 9.560168614900268
#
# metric: manhattan, weights: uniform, n_neighbors: 3, radius: 194, score: 9.563960597511718
#
# metric: manhattan, weights: uniform, n_neighbors: 3, radius: 195, score: 9.557728764180638
#
# metric: manhattan, weights: uniform, n_neighbors: 3, radius: 196, score: 9.566343949939249
#
# metric: manhattan, weights: uniform, n_neighbors: 3, radius: 197, score: 9.562370994523809
#
# metric: manhattan, weights: uniform, n_neighbors: 3, radius: 198, score: 9.554565342150783
#
# metric: manhattan, weights: uniform, n_neighbors: 3, radius: 199, score: 9.56817860135801
#
# metric: manhattan, weights: uniform, n_neighbors: 4, radius: 120, score: 9.975610016086128
#
# metric: manhattan, weights: uniform, n_neighbors: 4, radius: 121, score: 9.980180492275656
#
# metric: manhattan, weights: uniform, n_neighbors: 4, radius: 122, score: 9.957426428827823
#
# metric: manhattan, weights: uniform, n_neighbors: 4, radius: 123, score: 9.944501760593567
#
# metric: manhattan, weights: uniform, n_neighbors: 4, radius: 124, score: 9.945624313220788
#
# metric: manhattan, weights: uniform, n_neighbors: 4, radius: 125, score: 9.947630113282726
#
# metric: manhattan, weights: uniform, n_neighbors: 4, radius: 126, score: 9.944307960853148
#
# metric: manhattan, weights: uniform, n_neighbors: 4, radius: 127, score: 9.962038142609906
#
# metric: manhattan, weights: uniform, n_neighbors: 4, radius: 128, score: 9.966793417332116
#
# metric: manhattan, weights: uniform, n_neighbors: 4, radius: 129, score: 9.983198248920491
#
# metric: manhattan, weights: uniform, n_neighbors: 4, radius: 130, score: 9.983198248920491
#
# metric: manhattan, weights: uniform, n_neighbors: 4, radius: 131, score: 9.987989176465197
#
# metric: manhattan, weights: uniform, n_neighbors: 4, radius: 132, score: 9.971591205817107
#
# metric: manhattan, weights: uniform, n_neighbors: 4, radius: 133, score: 9.975733705240563
#
# metric: manhattan, weights: uniform, n_neighbors: 4, radius: 134, score: 9.95511813551541
#
# metric: manhattan, weights: uniform, n_neighbors: 4, radius: 135, score: 9.966679159960112
#
# metric: manhattan, weights: uniform, n_neighbors: 4, radius: 136, score: 9.96757080797641
#
# metric: manhattan, weights: uniform, n_neighbors: 4, radius: 137, score: 9.971078809727357
#
# metric: manhattan, weights: uniform, n_neighbors: 4, radius: 138, score: 9.958354558196287
#
# metric: manhattan, weights: uniform, n_neighbors: 4, radius: 139, score: 9.96191869058298
#
# metric: manhattan, weights: uniform, n_neighbors: 4, radius: 140, score: 9.970890854260682
#
# metric: manhattan, weights: uniform, n_neighbors: 4, radius: 141, score: 9.950722206845203
#
# metric: manhattan, weights: uniform, n_neighbors: 4, radius: 142, score: 9.97218591386509
#
# metric: manhattan, weights: uniform, n_neighbors: 4, radius: 143, score: 9.963305381207785
#
# metric: manhattan, weights: uniform, n_neighbors: 4, radius: 144, score: 9.947158601595097
#
# metric: manhattan, weights: uniform, n_neighbors: 4, radius: 145, score: 9.787551261661502
#
# metric: manhattan, weights: uniform, n_neighbors: 4, radius: 146, score: 9.788739779550085
#
# metric: manhattan, weights: uniform, n_neighbors: 4, radius: 147, score: 9.801383989955458
#
# metric: manhattan, weights: uniform, n_neighbors: 4, radius: 148, score: 9.802603743333215
#
# metric: manhattan, weights: uniform, n_neighbors: 4, radius: 149, score: 9.803982863704139
#
# metric: manhattan, weights: uniform, n_neighbors: 4, radius: 150, score: 9.813513022438828
#
# metric: manhattan, weights: uniform, n_neighbors: 4, radius: 151, score: 9.812649291489354
#
# metric: manhattan, weights: uniform, n_neighbors: 4, radius: 152, score: 9.79424562711013
#
# metric: manhattan, weights: uniform, n_neighbors: 4, radius: 153, score: 9.772655072894477
#
# metric: manhattan, weights: uniform, n_neighbors: 4, radius: 154, score: 9.775494779855078
#
# metric: manhattan, weights: uniform, n_neighbors: 4, radius: 155, score: 9.769656286953937
#
# metric: manhattan, weights: uniform, n_neighbors: 4, radius: 156, score: 9.785346323465937
#
# metric: manhattan, weights: uniform, n_neighbors: 4, radius: 157, score: 9.773771071737176
#
# metric: manhattan, weights: uniform, n_neighbors: 4, radius: 158, score: 9.838126042270071
#
# metric: manhattan, weights: uniform, n_neighbors: 4, radius: 159, score: 9.809622412044913
#
# metric: manhattan, weights: uniform, n_neighbors: 4, radius: 160, score: 9.812152633837325
#
# metric: manhattan, weights: uniform, n_neighbors: 4, radius: 161, score: 9.842186072405962
#
# metric: manhattan, weights: uniform, n_neighbors: 4, radius: 162, score: 9.830049364318603
#
# metric: manhattan, weights: uniform, n_neighbors: 4, radius: 163, score: 9.818732642664
#
# metric: manhattan, weights: uniform, n_neighbors: 4, radius: 164, score: 9.810166522391631
#
# metric: manhattan, weights: uniform, n_neighbors: 4, radius: 165, score: 9.8115964378112
#
# metric: manhattan, weights: uniform, n_neighbors: 4, radius: 166, score: 9.83306926181838
#
# metric: manhattan, weights: uniform, n_neighbors: 4, radius: 167, score: 9.825894219692682
#
# metric: manhattan, weights: uniform, n_neighbors: 4, radius: 168, score: 9.824090047029706
#
# metric: manhattan, weights: uniform, n_neighbors: 4, radius: 169, score: 9.81445994678678
#
# metric: manhattan, weights: uniform, n_neighbors: 4, radius: 170, score: 9.827100897766668
#
# metric: manhattan, weights: uniform, n_neighbors: 4, radius: 171, score: 9.836163291257268
#
# metric: manhattan, weights: uniform, n_neighbors: 4, radius: 172, score: 9.861911755513246
#
# metric: manhattan, weights: uniform, n_neighbors: 4, radius: 173, score: 9.869376609638419
#
# metric: manhattan, weights: uniform, n_neighbors: 4, radius: 174, score: 9.844405026885816
#
# metric: manhattan, weights: uniform, n_neighbors: 4, radius: 175, score: 9.853254864490669
#
# metric: manhattan, weights: uniform, n_neighbors: 4, radius: 176, score: 9.845158907946336
#
# metric: manhattan, weights: uniform, n_neighbors: 4, radius: 177, score: 9.775670477982768
#
# metric: manhattan, weights: uniform, n_neighbors: 4, radius: 178, score: 9.75240998413054
#
# metric: manhattan, weights: uniform, n_neighbors: 4, radius: 179, score: 9.722143839238466
#
# metric: manhattan, weights: uniform, n_neighbors: 4, radius: 180, score: 9.724759910464556
#
# metric: manhattan, weights: uniform, n_neighbors: 4, radius: 181, score: 9.725949048112033
#
# metric: manhattan, weights: uniform, n_neighbors: 4, radius: 182, score: 9.693055414550782
#
# metric: manhattan, weights: uniform, n_neighbors: 4, radius: 183, score: 9.681941846845737
#
# metric: manhattan, weights: uniform, n_neighbors: 4, radius: 184, score: 9.67884707990715
#
# metric: manhattan, weights: uniform, n_neighbors: 4, radius: 185, score: 9.676180526777232
#
# metric: manhattan, weights: uniform, n_neighbors: 4, radius: 186, score: 9.68776161233819
#
# metric: manhattan, weights: uniform, n_neighbors: 4, radius: 187, score: 9.667296954775034
#
# metric: manhattan, weights: uniform, n_neighbors: 4, radius: 188, score: 9.635681007475295
#
# metric: manhattan, weights: uniform, n_neighbors: 4, radius: 189, score: 9.639263976144699
#
# metric: manhattan, weights: uniform, n_neighbors: 4, radius: 190, score: 9.633481555103868
#
# metric: manhattan, weights: uniform, n_neighbors: 4, radius: 191, score: 9.669307211633342
#
# metric: manhattan, weights: uniform, n_neighbors: 4, radius: 192, score: 9.597380324781488
#
# metric: manhattan, weights: uniform, n_neighbors: 4, radius: 193, score: 9.59256785425534
#
# metric: manhattan, weights: uniform, n_neighbors: 4, radius: 194, score: 9.596359836866789
#
# metric: manhattan, weights: uniform, n_neighbors: 4, radius: 195, score: 9.584010399322628
#
# metric: manhattan, weights: uniform, n_neighbors: 4, radius: 196, score: 9.59200458691198
#
# metric: manhattan, weights: uniform, n_neighbors: 4, radius: 197, score: 9.601799484575224
#
# metric: manhattan, weights: uniform, n_neighbors: 4, radius: 198, score: 9.59354934756968
#
# metric: manhattan, weights: uniform, n_neighbors: 4, radius: 199, score: 9.61425906862199
#
# metric: manhattan, weights: uniform, n_neighbors: 5, radius: 120, score: 9.985787850538081
#
# metric: manhattan, weights: uniform, n_neighbors: 5, radius: 121, score: 9.990358326727609
#
# metric: manhattan, weights: uniform, n_neighbors: 5, radius: 122, score: 9.967604263279778
#
# metric: manhattan, weights: uniform, n_neighbors: 5, radius: 123, score: 9.954679595045521
#
# metric: manhattan, weights: uniform, n_neighbors: 5, radius: 124, score: 9.952833881006807
#
# metric: manhattan, weights: uniform, n_neighbors: 5, radius: 125, score: 9.954798131617544
#
# metric: manhattan, weights: uniform, n_neighbors: 5, radius: 126, score: 9.951475979187967
#
# metric: manhattan, weights: uniform, n_neighbors: 5, radius: 127, score: 9.96570437820188
#
# metric: manhattan, weights: uniform, n_neighbors: 5, radius: 128, score: 9.97045965292409
#
# metric: manhattan, weights: uniform, n_neighbors: 5, radius: 129, score: 9.989079780245376
#
# metric: manhattan, weights: uniform, n_neighbors: 5, radius: 130, score: 9.989079780245376
#
# metric: manhattan, weights: uniform, n_neighbors: 5, radius: 131, score: 9.99489686797459
#
# metric: manhattan, weights: uniform, n_neighbors: 5, radius: 132, score: 9.978498897326501
#
# metric: manhattan, weights: uniform, n_neighbors: 5, radius: 133, score: 9.982641396749958
#
# metric: manhattan, weights: uniform, n_neighbors: 5, radius: 134, score: 9.962025827024803
#
# metric: manhattan, weights: uniform, n_neighbors: 5, radius: 135, score: 9.9750305459145
#
# metric: manhattan, weights: uniform, n_neighbors: 5, radius: 136, score: 9.972594708654922
#
# metric: manhattan, weights: uniform, n_neighbors: 5, radius: 137, score: 9.976102710405872
#
# metric: manhattan, weights: uniform, n_neighbors: 5, radius: 138, score: 9.964245630324244
#
# metric: manhattan, weights: uniform, n_neighbors: 5, radius: 139, score: 9.965260504468421
#
# metric: manhattan, weights: uniform, n_neighbors: 5, radius: 140, score: 9.97236742089247
#
# metric: manhattan, weights: uniform, n_neighbors: 5, radius: 141, score: 9.951998829033402
#
# metric: manhattan, weights: uniform, n_neighbors: 5, radius: 142, score: 10.00742948876627
#
# metric: manhattan, weights: uniform, n_neighbors: 5, radius: 143, score: 9.998548956108966
#
# metric: manhattan, weights: uniform, n_neighbors: 5, radius: 144, score: 9.982402176496281
#
# metric: manhattan, weights: uniform, n_neighbors: 5, radius: 145, score: 9.825094798099641
#
# metric: manhattan, weights: uniform, n_neighbors: 5, radius: 146, score: 9.82732429950331
#
# metric: manhattan, weights: uniform, n_neighbors: 5, radius: 147, score: 9.839968509908681
#
# metric: manhattan, weights: uniform, n_neighbors: 5, radius: 148, score: 9.84118826328644
#
# metric: manhattan, weights: uniform, n_neighbors: 5, radius: 149, score: 9.843204696844651
#
# metric: manhattan, weights: uniform, n_neighbors: 5, radius: 150, score: 9.852734855579337
#
# metric: manhattan, weights: uniform, n_neighbors: 5, radius: 151, score: 9.853027316947186
#
# metric: manhattan, weights: uniform, n_neighbors: 5, radius: 152, score: 9.83868424701264
#
# metric: manhattan, weights: uniform, n_neighbors: 5, radius: 153, score: 9.819140260833569
#
# metric: manhattan, weights: uniform, n_neighbors: 5, radius: 154, score: 9.838911795354031
#
# metric: manhattan, weights: uniform, n_neighbors: 5, radius: 155, score: 9.83307330245289
#
# metric: manhattan, weights: uniform, n_neighbors: 5, radius: 156, score: 9.844690855448887
#
# metric: manhattan, weights: uniform, n_neighbors: 5, radius: 157, score: 9.832456009275361
#
# metric: manhattan, weights: uniform, n_neighbors: 5, radius: 158, score: 9.894445534711597
#
# metric: manhattan, weights: uniform, n_neighbors: 5, radius: 159, score: 9.86751183781915
#
# metric: manhattan, weights: uniform, n_neighbors: 5, radius: 160, score: 9.871848427743654
#
# metric: manhattan, weights: uniform, n_neighbors: 5, radius: 161, score: 9.904821680511052
#
# metric: manhattan, weights: uniform, n_neighbors: 5, radius: 162, score: 9.892684972423694
#
# metric: manhattan, weights: uniform, n_neighbors: 5, radius: 163, score: 9.96213841352554
#
# metric: manhattan, weights: uniform, n_neighbors: 5, radius: 164, score: 9.961113979991143
#
# metric: manhattan, weights: uniform, n_neighbors: 5, radius: 165, score: 9.959474356552992
#
# metric: manhattan, weights: uniform, n_neighbors: 5, radius: 166, score: 9.980947180560173
#
# metric: manhattan, weights: uniform, n_neighbors: 5, radius: 167, score: 9.977149878409913
#
# metric: manhattan, weights: uniform, n_neighbors: 5, radius: 168, score: 9.973792732548144
#
# metric: manhattan, weights: uniform, n_neighbors: 5, radius: 169, score: 9.972628885198015
#
# metric: manhattan, weights: uniform, n_neighbors: 5, radius: 170, score: 9.987473653768001
#
# metric: manhattan, weights: uniform, n_neighbors: 5, radius: 171, score: 9.996536047258601
#
# metric: manhattan, weights: uniform, n_neighbors: 5, radius: 172, score: 10.018972714261844
#
# metric: manhattan, weights: uniform, n_neighbors: 5, radius: 173, score: 10.026805247658983
#
# metric: manhattan, weights: uniform, n_neighbors: 5, radius: 174, score: 9.997908507571683
#
# metric: manhattan, weights: uniform, n_neighbors: 5, radius: 175, score: 10.0141818272261
#
# metric: manhattan, weights: uniform, n_neighbors: 5, radius: 176, score: 10.003696457323155
#
# metric: manhattan, weights: uniform, n_neighbors: 5, radius: 177, score: 9.934208027359585
#
# metric: manhattan, weights: uniform, n_neighbors: 5, radius: 178, score: 9.912563061284775
#
# metric: manhattan, weights: uniform, n_neighbors: 5, radius: 179, score: 9.885595073723614
#
# metric: manhattan, weights: uniform, n_neighbors: 5, radius: 180, score: 9.894869146299587
#
# metric: manhattan, weights: uniform, n_neighbors: 5, radius: 181, score: 9.900611716756142
#
# metric: manhattan, weights: uniform, n_neighbors: 5, radius: 182, score: 9.868638753513135
#
# metric: manhattan, weights: uniform, n_neighbors: 5, radius: 183, score: 9.858722124697604
#
# metric: manhattan, weights: uniform, n_neighbors: 5, radius: 184, score: 9.853575640262246
#
# metric: manhattan, weights: uniform, n_neighbors: 5, radius: 185, score: 9.844922870464705
#
# metric: manhattan, weights: uniform, n_neighbors: 5, radius: 186, score: 9.858744346135362
#
# metric: manhattan, weights: uniform, n_neighbors: 5, radius: 187, score: 9.834579753382382
#
# metric: manhattan, weights: uniform, n_neighbors: 5, radius: 188, score: 9.799352489171298
#
# metric: manhattan, weights: uniform, n_neighbors: 5, radius: 189, score: 9.798177827379314
#
# metric: manhattan, weights: uniform, n_neighbors: 5, radius: 190, score: 9.794070782678782
#
# metric: manhattan, weights: uniform, n_neighbors: 5, radius: 191, score: 9.827939420071967
#
# metric: manhattan, weights: uniform, n_neighbors: 5, radius: 192, score: 9.75959001890544
#
# metric: manhattan, weights: uniform, n_neighbors: 5, radius: 193, score: 9.753254048378949
#
# metric: manhattan, weights: uniform, n_neighbors: 5, radius: 194, score: 9.773269398149418
#
# metric: manhattan, weights: uniform, n_neighbors: 5, radius: 195, score: 9.760919960605255
#
# metric: manhattan, weights: uniform, n_neighbors: 5, radius: 196, score: 9.770328002886153
#
# metric: manhattan, weights: uniform, n_neighbors: 5, radius: 197, score: 9.785849673431033
#
# metric: manhattan, weights: uniform, n_neighbors: 5, radius: 198, score: 9.772355062592277
#
# metric: manhattan, weights: uniform, n_neighbors: 5, radius: 199, score: 9.790395843197453
# {'metric': 'euclidean', 'weights': 'uniform', 'n_neighbors': 2, 'radius': 120}

# %%
knn_model = KNeighborsRegressor(**best_params)
knn_model.fit(X, y)

pred = knn_model.predict(X_valid)

pred_lon = pred[:, 0]
pred_lat = pred[:, 1]
pred_floor = np.round(pred[:, 2], decimals=0)
pred_building = np.round(pred[:, 3], decimals=0)

distance = distance75(y_valid, pred)
score = np.mean(distance)
lon_score = np.mean(np.absolute(pred_lon - y_valid.lon))
lat_score = np.mean(np.absolute(pred_lat - y_valid.lat))
right_floor = np.round(np.mean(pred_floor == y_valid.floor) * 100, 2)
right_building = np.round(np.mean(pred_building == y_valid.building) * 100, 2)

predictions = pd.DataFrame(
    {
        "LATITUDE": pred_lat,
        "LONGITUDE": pred_lon,
        "FLOOR": pred_floor,
        "distance": distance,
    }
)

true_values = pd.DataFrame(
    {
        "LATITUDE": y_valid.lat,
        "LONGITUDE": y_valid.lon,
        "FLOOR": y_valid.floor,
        "distance": distance,
    }
)
# Out:
# KNeighborsRegressor(algorithm='auto', leaf_size=30, metric='euclidean',
#                     metric_params=None, n_jobs=None, n_neighbors=2, p=2,
#                     weights='uniform')

# %%
print(f"Mean error in distance75: {score}")
print(f"Latitude error: {lat_score}")
print(f"Longitude error: {lon_score}")
print(f"Floors correct: {right_floor} %")
print(f"Building correct: {right_building} %")

for floor in sorted(predictions.FLOOR.unique()):
    fig, ax = plt.subplots()
    sns.scatterplot(
        x="LONGITUDE",
        y="LATITUDE",
        hue="distance",
        ax=ax,
        s=100,
        data=predictions[predictions["FLOOR"] == int(floor)],
    )
    ax.set_aspect(aspect="equal")
    plt.title(f"Predictions Floor {int(floor)}")
    plt.show()

    fig, ax = plt.subplots()
    sns.scatterplot(
        x="LONGITUDE",
        y="LATITUDE",
        hue="distance",
        s=100,
        data=true_values[true_values["FLOOR"] == int(floor)],
        ax=ax,
    )
    ax.set_aspect(aspect="equal")
    plt.title(f"Real Values Floor {int(floor)}")
    plt.show()
# Out:
# Mean error in distance75: 13.893534135917843
# Latitude error: 6.379425221505892
# Longitude error: 6.750832586779186
# Floors correct: 87.13 %
# Building correct: 99.64 %
# Text(0.5, 1.0, 'Predictions Floor 0')
# Text(0.5, 1.0, 'Real Values Floor 0')
# Text(0.5, 1.0, 'Predictions Floor 1')
# Text(0.5, 1.0, 'Real Values Floor 1')
# Text(0.5, 1.0, 'Predictions Floor 2')
# Text(0.5, 1.0, 'Real Values Floor 2')
# Text(0.5, 1.0, 'Predictions Floor 3')
# Text(0.5, 1.0, 'Real Values Floor 3')
# Text(0.5, 1.0, 'Predictions Floor 4')
# Text(0.5, 1.0, 'Real Values Floor 4')

# %%
predictions.distance.hist(bins=100)
