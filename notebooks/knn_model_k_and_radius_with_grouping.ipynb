# %%
# Change directory to VSCode workspace root so that relative path loads work correctly. Turn this addition off with the DataScience.changeDirOnImportExport setting
# ms-python.python added
import os
try:
	os.chdir(os.path.join(os.getcwd(), '..'))
	print(os.getcwd())
except:
	pass

# %%
import os

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
from IPython.core.interactiveshell import InteractiveShell
from sklearn.base import BaseEstimator
from sklearn.metrics import make_scorer
from sklearn.model_selection import cross_val_score, train_test_split
from sklearn.neighbors import KNeighborsRegressor

# Setting styles
InteractiveShell.ast_node_interactivity = "all"
sns.set(style="whitegrid", color_codes=True, rc={"figure.figsize": (12.7, 9.27)})

random_state = 123

# %%
df = pd.read_csv(os.path.join("data", "processed", "train.csv"))
df = df.drop(columns=["train"])

df_valid = pd.read_csv(os.path.join("data", "processed", "test.csv"))
df_valid = df_valid.drop(columns=["train", "spaceid", "relativeposition"])

# %%
# this drops the amount of datapoints by 95 %
df = df.groupby(
    ["buildingid", "floor", "spaceid", "relativeposition"], as_index=False
).mean()

df.drop(columns=["spaceid", "relativeposition"], inplace=True)

# %%
X = df.drop(columns=["longitude", "latitude", "floor", "buildingid"])
y_lon = df.longitude
y_lat = df.latitude
y_floor = df.floor
y = pd.DataFrame({"lon": y_lon, "lat": y_lat, "floor": y_floor})

X_valid = df_valid.drop(columns=["longitude", "latitude", "floor", "buildingid"])
y_valid_lon = df_valid.longitude
y_valid_lat = df_valid.latitude
y_valid_floor = df_valid.floor
y_valid = pd.DataFrame({"lon": y_valid_lon, "lat": y_valid_lat, "floor": y_valid_floor})

# %%
X_train, X_test, y_train_lon, y_test_lon = train_test_split(
    X,
    y_lon,
    test_size=0.2,
    random_state=random_state,
    stratify=df[["buildingid", "floor"]],
)

_, _, y_train_lat, y_test_lat = train_test_split(
    X,
    y_lat,
    test_size=0.2,
    random_state=random_state,
    stratify=df[["buildingid", "floor"]],
)

_, _, y_train_floor, y_test_floor = train_test_split(
    X,
    y_floor,
    test_size=0.2,
    random_state=random_state,
    stratify=df[["buildingid", "floor"]],
)

y_train = pd.DataFrame({"lon": y_train_lon, "lat": y_train_lat, "floor": y_train_floor})
y_test = pd.DataFrame({"lon": y_test_lon, "lat": y_test_lat, "floor": y_test_floor})

# %%
def _get_weights(dist, weights):
    """Get the weights from an array of distances and a parameter ``weights``

    Parameters
    ----------
    dist : ndarray
        The input distances
    weights : {'uniform', 'distance' or a callable}
        The kind of weighting used

    Returns
    -------
    weights_arr : array of the same shape as ``dist``
        if ``weights == 'uniform'``, then returns None
    """
    if weights in (None, "uniform"):
        return None
    elif weights == "distance":
        # if user attempts to classify a point that was zero distance from one
        # or more training points, those training points are weighted as 1.0
        # and the other points as 0.0
        if dist.dtype is np.dtype(object):
            for point_dist_i, point_dist in enumerate(dist):
                # check if point_dist is iterable
                # (ex: RadiusNeighborClassifier.predict may set an element of
                # dist to 1e-6 to represent an 'outlier')
                if hasattr(point_dist, "__contains__") and 0.0 in point_dist:
                    dist[point_dist_i] = point_dist == 0.0
                else:
                    dist[point_dist_i] = 1.0 / point_dist
        else:
            with np.errstate(divide="ignore"):
                dist = 1.0 / dist
            inf_mask = np.isinf(dist)
            inf_row = np.any(inf_mask, axis=1)
            dist[inf_row] = inf_mask[inf_row]
        return dist
    elif callable(weights):
        return weights(dist)
    else:
        raise ValueError(
            "weights not recognized: should be 'uniform', "
            "'distance', or a callable function"
        )


class kradius(BaseEstimator):
    def __init__(
        self, metric="euclidean", weights="uniform", n_neighbors=3, radius=1.0, n_jobs=1
    ):
        self.radius = radius
        self.metric = metric
        self.weights = weights
        self.n_neighbors = n_neighbors
        self.n_jobs = n_jobs

    def fit(self, X, y):
        self.knn_model = KNeighborsRegressor(
            n_neighbors=self.n_neighbors,
            n_jobs=self.n_jobs,
            weights=self.weights,
            metric=self.metric,
        )
        self.knn_model.fit(X, y)
        return self

    def predict(self, X):

        # no need to to distance filtering if we take only 1 neighbor
        if self.n_neighbors > 1:

            _y = self.knn_model._y

            dists, inds = self.knn_model.kneighbors(X, n_neighbors=self.n_neighbors)
            # dropping value where distance too big
            # we always keep the closest point (first value)
            inds = [
                np.array(
                    [
                        index
                        for distance, index in zip(dist, ind)
                        if distance <= self.radius or distance == dist[0]
                    ]
                )
                for dist, ind in zip(dists, inds)
            ]
            dists = [
                np.array(
                    [
                        distance
                        for distance in dist
                        if distance <= self.radius or distance == dist[0]
                    ]
                )
                for dist in dists
            ]

            weights = _get_weights(dists, self.weights)

            empty_obs = np.full_like(_y[0], np.nan)

            if weights is None:
                y_pred = np.array(
                    [
                        np.mean(_y[ind, :], axis=0) if len(ind) else empty_obs
                        for (i, ind) in enumerate(inds)
                    ]
                )

            else:
                y_pred = np.array(
                    [
                        np.average(_y[ind, :], axis=0, weights=weights[i])
                        if len(ind)
                        else empty_obs
                        for (i, ind) in enumerate(inds)
                    ]
                )

            return y_pred

        else:
            return self.knn_model.predict(X)

# %%
def calculate_distance(y, y_pred):
    pred_lon = y_pred[:, 0]
    pred_lat = y_pred[:, 1]
    pred_floor = y_pred[:, 2]

    lon_diff2 = (pred_lon - y.lon) ** 2
    lat_diff2 = (pred_lat - y.lat) ** 2
    # lets assume that the height of the floors is 5 meters
    floor_diff2 = ((pred_floor - y.floor) * 5) ** 2

    distance_squared = lon_diff2 + lat_diff2 + floor_diff2

    mean_distance = distance_squared.apply(lambda x: x ** (1 / 2)).mean()

    return mean_distance


distance_scorer = make_scorer(calculate_distance, greater_is_better=False)


def squared_distance(weights):
    # replacing zero values with machine epsilon
    weights[weights == 0] = np.finfo(float).eps
    weights = [
        (1 / weights_obs ** 2) / np.sum(1 / weights_obs ** 2) for weights_obs in weights
    ]
    return weights


metric_opt = ["euclidean", "manhattan"]
weights_opt = ["uniform"]
n_neighbors_opt = range(1, 6)
radius_opt = np.arange(120, 200, step=1)

best_score = None
for metric in metric_opt:
    for weights in weights_opt:
        for n_neighbors in n_neighbors_opt:
            # no need to check for are if just one k
            if n_neighbors == 1:
                radius_opt_modified = [1]
            else:
                radius_opt_modified = radius_opt.copy()

            for radius in radius_opt_modified:
                kradius_model = kradius(
                    metric=metric,
                    weights=weights,
                    n_neighbors=n_neighbors,
                    radius=radius,
                    n_jobs=1,
                )
                cv_val_scores = cross_val_score(
                    kradius_model, X=X, y=y, scoring=distance_scorer, cv=5, n_jobs=-2
                )
                score = -cv_val_scores.mean()
                print()
                print(
                    f"metric: {metric}, weights: {weights}, n_neighbors: {n_neighbors}, radius: {radius}, score: {score}"
                )
                if best_score is None or best_score > score:
                    print("new best score found!")
                    best_score = score
                    best_params = {
                        "metric": metric,
                        "weights": weights,
                        "n_neighbors": n_neighbors,
                        "radius": radius,
                    }


print(best_params)
# Out:
# 4059054358694
#
# metric: manhattan, weights: uniform, n_neighbors: 3, radius: 144, score: 47.64059054358694
#
# metric: manhattan, weights: uniform, n_neighbors: 3, radius: 145, score: 47.64059054358694
#
# metric: manhattan, weights: uniform, n_neighbors: 3, radius: 146, score: 47.65009717265285
#
# metric: manhattan, weights: uniform, n_neighbors: 3, radius: 147, score: 47.66248330630391
#
# metric: manhattan, weights: uniform, n_neighbors: 3, radius: 148, score: 47.66248330630391
#
# metric: manhattan, weights: uniform, n_neighbors: 3, radius: 149, score: 47.66248330630391
#
# metric: manhattan, weights: uniform, n_neighbors: 3, radius: 150, score: 47.63843324313338
#
# metric: manhattan, weights: uniform, n_neighbors: 3, radius: 151, score: 47.67329180686379
#
# metric: manhattan, weights: uniform, n_neighbors: 3, radius: 152, score: 47.67329180686379
#
# metric: manhattan, weights: uniform, n_neighbors: 3, radius: 153, score: 47.68287039349682
#
# metric: manhattan, weights: uniform, n_neighbors: 3, radius: 154, score: 47.68287039349682
#
# metric: manhattan, weights: uniform, n_neighbors: 3, radius: 155, score: 47.68287039349682
#
# metric: manhattan, weights: uniform, n_neighbors: 3, radius: 156, score: 47.68287039349682
#
# metric: manhattan, weights: uniform, n_neighbors: 3, radius: 157, score: 47.69247691075454
#
# metric: manhattan, weights: uniform, n_neighbors: 3, radius: 158, score: 47.69247691075454
#
# metric: manhattan, weights: uniform, n_neighbors: 3, radius: 159, score: 47.69247691075454
#
# metric: manhattan, weights: uniform, n_neighbors: 3, radius: 160, score: 47.69247691075454
#
# metric: manhattan, weights: uniform, n_neighbors: 3, radius: 161, score: 47.69247691075454
#
# metric: manhattan, weights: uniform, n_neighbors: 3, radius: 162, score: 47.69247691075454
#
# metric: manhattan, weights: uniform, n_neighbors: 3, radius: 163, score: 47.69247691075454
#
# metric: manhattan, weights: uniform, n_neighbors: 3, radius: 164, score: 47.69247691075454
#
# metric: manhattan, weights: uniform, n_neighbors: 3, radius: 165, score: 47.69247691075454
#
# metric: manhattan, weights: uniform, n_neighbors: 3, radius: 166, score: 47.7105196895166
#
# metric: manhattan, weights: uniform, n_neighbors: 3, radius: 167, score: 47.7105196895166
#
# metric: manhattan, weights: uniform, n_neighbors: 3, radius: 168, score: 47.7105196895166
#
# metric: manhattan, weights: uniform, n_neighbors: 3, radius: 169, score: 47.711648050270526
#
# metric: manhattan, weights: uniform, n_neighbors: 3, radius: 170, score: 47.711648050270526
#
# metric: manhattan, weights: uniform, n_neighbors: 3, radius: 171, score: 47.711648050270526
#
# metric: manhattan, weights: uniform, n_neighbors: 3, radius: 172, score: 47.73089273799684
#
# metric: manhattan, weights: uniform, n_neighbors: 3, radius: 173, score: 47.73089273799684
#
# metric: manhattan, weights: uniform, n_neighbors: 3, radius: 174, score: 47.73541625274974
#
# metric: manhattan, weights: uniform, n_neighbors: 3, radius: 175, score: 47.73541625274974
#
# metric: manhattan, weights: uniform, n_neighbors: 3, radius: 176, score: 47.73541625274974
#
# metric: manhattan, weights: uniform, n_neighbors: 3, radius: 177, score: 47.70754928570176
#
# metric: manhattan, weights: uniform, n_neighbors: 3, radius: 178, score: 47.70754928570176
#
# metric: manhattan, weights: uniform, n_neighbors: 3, radius: 179, score: 47.70754928570176
#
# metric: manhattan, weights: uniform, n_neighbors: 3, radius: 180, score: 47.71045364573579
#
# metric: manhattan, weights: uniform, n_neighbors: 3, radius: 181, score: 47.71310042678069
#
# metric: manhattan, weights: uniform, n_neighbors: 3, radius: 182, score: 47.71310042678069
#
# metric: manhattan, weights: uniform, n_neighbors: 3, radius: 183, score: 47.71310042678069
#
# metric: manhattan, weights: uniform, n_neighbors: 3, radius: 184, score: 47.728479699812205
#
# metric: manhattan, weights: uniform, n_neighbors: 3, radius: 185, score: 47.728479699812205
#
# metric: manhattan, weights: uniform, n_neighbors: 3, radius: 186, score: 47.728479699812205
#
# metric: manhattan, weights: uniform, n_neighbors: 3, radius: 187, score: 47.728479699812205
#
# metric: manhattan, weights: uniform, n_neighbors: 3, radius: 188, score: 47.75279975783675
#
# metric: manhattan, weights: uniform, n_neighbors: 3, radius: 189, score: 47.75049183047914
#
# metric: manhattan, weights: uniform, n_neighbors: 3, radius: 190, score: 47.75049183047914
#
# metric: manhattan, weights: uniform, n_neighbors: 3, radius: 191, score: 47.75049183047914
#
# metric: manhattan, weights: uniform, n_neighbors: 3, radius: 192, score: 47.718013270196934
#
# metric: manhattan, weights: uniform, n_neighbors: 3, radius: 193, score: 47.69256731223112
#
# metric: manhattan, weights: uniform, n_neighbors: 3, radius: 194, score: 47.6988890127864
#
# metric: manhattan, weights: uniform, n_neighbors: 3, radius: 195, score: 47.6988890127864
#
# metric: manhattan, weights: uniform, n_neighbors: 3, radius: 196, score: 47.73212890917182
#
# metric: manhattan, weights: uniform, n_neighbors: 3, radius: 197, score: 47.75505096996462
#
# metric: manhattan, weights: uniform, n_neighbors: 3, radius: 198, score: 47.756398580240294
#
# metric: manhattan, weights: uniform, n_neighbors: 3, radius: 199, score: 47.73572924559428
#
# metric: manhattan, weights: uniform, n_neighbors: 4, radius: 120, score: 47.63617891214153
#
# metric: manhattan, weights: uniform, n_neighbors: 4, radius: 121, score: 47.63617891214153
#
# metric: manhattan, weights: uniform, n_neighbors: 4, radius: 122, score: 47.63617891214153
#
# metric: manhattan, weights: uniform, n_neighbors: 4, radius: 123, score: 47.63617891214153
#
# metric: manhattan, weights: uniform, n_neighbors: 4, radius: 124, score: 47.63617891214153
#
# metric: manhattan, weights: uniform, n_neighbors: 4, radius: 125, score: 47.62870226433729
#
# metric: manhattan, weights: uniform, n_neighbors: 4, radius: 126, score: 47.62870226433729
#
# metric: manhattan, weights: uniform, n_neighbors: 4, radius: 127, score: 47.62870226433729
#
# metric: manhattan, weights: uniform, n_neighbors: 4, radius: 128, score: 47.62870226433729
#
# metric: manhattan, weights: uniform, n_neighbors: 4, radius: 129, score: 47.606052132756034
#
# metric: manhattan, weights: uniform, n_neighbors: 4, radius: 130, score: 47.606052132756034
#
# metric: manhattan, weights: uniform, n_neighbors: 4, radius: 131, score: 47.604900397087455
#
# metric: manhattan, weights: uniform, n_neighbors: 4, radius: 132, score: 47.604900397087455
#
# metric: manhattan, weights: uniform, n_neighbors: 4, radius: 133, score: 47.602624397636205
#
# metric: manhattan, weights: uniform, n_neighbors: 4, radius: 134, score: 47.602624397636205
#
# metric: manhattan, weights: uniform, n_neighbors: 4, radius: 135, score: 47.602624397636205
#
# metric: manhattan, weights: uniform, n_neighbors: 4, radius: 136, score: 47.602624397636205
#
# metric: manhattan, weights: uniform, n_neighbors: 4, radius: 137, score: 47.602624397636205
#
# metric: manhattan, weights: uniform, n_neighbors: 4, radius: 138, score: 47.61547170148716
#
# metric: manhattan, weights: uniform, n_neighbors: 4, radius: 139, score: 47.62905613527114
#
# metric: manhattan, weights: uniform, n_neighbors: 4, radius: 140, score: 47.62905613527114
#
# metric: manhattan, weights: uniform, n_neighbors: 4, radius: 141, score: 47.62905613527114
#
# metric: manhattan, weights: uniform, n_neighbors: 4, radius: 142, score: 47.630291694139416
#
# metric: manhattan, weights: uniform, n_neighbors: 4, radius: 143, score: 47.623776151245366
#
# metric: manhattan, weights: uniform, n_neighbors: 4, radius: 144, score: 47.623776151245366
#
# metric: manhattan, weights: uniform, n_neighbors: 4, radius: 145, score: 47.623776151245366
#
# metric: manhattan, weights: uniform, n_neighbors: 4, radius: 146, score: 47.633282780311276
#
# metric: manhattan, weights: uniform, n_neighbors: 4, radius: 147, score: 47.645668913962325
#
# metric: manhattan, weights: uniform, n_neighbors: 4, radius: 148, score: 47.645668913962325
#
# metric: manhattan, weights: uniform, n_neighbors: 4, radius: 149, score: 47.645668913962325
#
# metric: manhattan, weights: uniform, n_neighbors: 4, radius: 150, score: 47.6216188507918
#
# metric: manhattan, weights: uniform, n_neighbors: 4, radius: 151, score: 47.656477414522215
#
# metric: manhattan, weights: uniform, n_neighbors: 4, radius: 152, score: 47.656477414522215
#
# metric: manhattan, weights: uniform, n_neighbors: 4, radius: 153, score: 47.66418038158091
#
# metric: manhattan, weights: uniform, n_neighbors: 4, radius: 154, score: 47.66418038158091
#
# metric: manhattan, weights: uniform, n_neighbors: 4, radius: 155, score: 47.66418038158091
#
# metric: manhattan, weights: uniform, n_neighbors: 4, radius: 156, score: 47.66418038158091
#
# metric: manhattan, weights: uniform, n_neighbors: 4, radius: 157, score: 47.67378689883865
#
# metric: manhattan, weights: uniform, n_neighbors: 4, radius: 158, score: 47.67378689883865
#
# metric: manhattan, weights: uniform, n_neighbors: 4, radius: 159, score: 47.67378689883865
#
# metric: manhattan, weights: uniform, n_neighbors: 4, radius: 160, score: 47.67378689883865
#
# metric: manhattan, weights: uniform, n_neighbors: 4, radius: 161, score: 47.67378689883865
#
# metric: manhattan, weights: uniform, n_neighbors: 4, radius: 162, score: 47.67378689883865
#
# metric: manhattan, weights: uniform, n_neighbors: 4, radius: 163, score: 47.67378689883865
#
# metric: manhattan, weights: uniform, n_neighbors: 4, radius: 164, score: 47.67378689883865
#
# metric: manhattan, weights: uniform, n_neighbors: 4, radius: 165, score: 47.67378689883865
#
# metric: manhattan, weights: uniform, n_neighbors: 4, radius: 166, score: 47.691829677600694
#
# metric: manhattan, weights: uniform, n_neighbors: 4, radius: 167, score: 47.691829677600694
#
# metric: manhattan, weights: uniform, n_neighbors: 4, radius: 168, score: 47.691829677600694
#
# metric: manhattan, weights: uniform, n_neighbors: 4, radius: 169, score: 47.69295803835462
#
# metric: manhattan, weights: uniform, n_neighbors: 4, radius: 170, score: 47.694656174895364
#
# metric: manhattan, weights: uniform, n_neighbors: 4, radius: 171, score: 47.694656174895364
#
# metric: manhattan, weights: uniform, n_neighbors: 4, radius: 172, score: 47.71390086262168
#
# metric: manhattan, weights: uniform, n_neighbors: 4, radius: 173, score: 47.71390086262168
#
# metric: manhattan, weights: uniform, n_neighbors: 4, radius: 174, score: 47.72195790435192
#
# metric: manhattan, weights: uniform, n_neighbors: 4, radius: 175, score: 47.72195790435192
#
# metric: manhattan, weights: uniform, n_neighbors: 4, radius: 176, score: 47.721879832427284
#
# metric: manhattan, weights: uniform, n_neighbors: 4, radius: 177, score: 47.695321700888975
#
# metric: manhattan, weights: uniform, n_neighbors: 4, radius: 178, score: 47.695321700888975
#
# metric: manhattan, weights: uniform, n_neighbors: 4, radius: 179, score: 47.695321700888975
#
# metric: manhattan, weights: uniform, n_neighbors: 4, radius: 180, score: 47.69822606092299
#
# metric: manhattan, weights: uniform, n_neighbors: 4, radius: 181, score: 47.70087284196789
#
# metric: manhattan, weights: uniform, n_neighbors: 4, radius: 182, score: 47.70087284196789
#
# metric: manhattan, weights: uniform, n_neighbors: 4, radius: 183, score: 47.70087284196789
#
# metric: manhattan, weights: uniform, n_neighbors: 4, radius: 184, score: 47.71625211499942
#
# metric: manhattan, weights: uniform, n_neighbors: 4, radius: 185, score: 47.714977388709386
#
# metric: manhattan, weights: uniform, n_neighbors: 4, radius: 186, score: 47.716696065690826
#
# metric: manhattan, weights: uniform, n_neighbors: 4, radius: 187, score: 47.716696065690826
#
# metric: manhattan, weights: uniform, n_neighbors: 4, radius: 188, score: 47.74101612371537
#
# metric: manhattan, weights: uniform, n_neighbors: 4, radius: 189, score: 47.73870819635776
#
# metric: manhattan, weights: uniform, n_neighbors: 4, radius: 190, score: 47.73870819635776
#
# metric: manhattan, weights: uniform, n_neighbors: 4, radius: 191, score: 47.73870819635776
#
# metric: manhattan, weights: uniform, n_neighbors: 4, radius: 192, score: 47.706229636075555
#
# metric: manhattan, weights: uniform, n_neighbors: 4, radius: 193, score: 47.6772409616479
#
# metric: manhattan, weights: uniform, n_neighbors: 4, radius: 194, score: 47.68356266220318
#
# metric: manhattan, weights: uniform, n_neighbors: 4, radius: 195, score: 47.68526137230789
#
# metric: manhattan, weights: uniform, n_neighbors: 4, radius: 196, score: 47.71850126869331
#
# metric: manhattan, weights: uniform, n_neighbors: 4, radius: 197, score: 47.74142332948611
#
# metric: manhattan, weights: uniform, n_neighbors: 4, radius: 198, score: 47.74242621856181
#
# metric: manhattan, weights: uniform, n_neighbors: 4, radius: 199, score: 47.72050168473142
#
# metric: manhattan, weights: uniform, n_neighbors: 5, radius: 120, score: 47.645223572157455
#
# metric: manhattan, weights: uniform, n_neighbors: 5, radius: 121, score: 47.645223572157455
#
# metric: manhattan, weights: uniform, n_neighbors: 5, radius: 122, score: 47.645223572157455
#
# metric: manhattan, weights: uniform, n_neighbors: 5, radius: 123, score: 47.645223572157455
#
# metric: manhattan, weights: uniform, n_neighbors: 5, radius: 124, score: 47.645223572157455
#
# metric: manhattan, weights: uniform, n_neighbors: 5, radius: 125, score: 47.63774692435321
#
# metric: manhattan, weights: uniform, n_neighbors: 5, radius: 126, score: 47.63774692435321
#
# metric: manhattan, weights: uniform, n_neighbors: 5, radius: 127, score: 47.63774692435321
#
# metric: manhattan, weights: uniform, n_neighbors: 5, radius: 128, score: 47.63774692435321
#
# metric: manhattan, weights: uniform, n_neighbors: 5, radius: 129, score: 47.61509679277195
#
# metric: manhattan, weights: uniform, n_neighbors: 5, radius: 130, score: 47.61509679277195
#
# metric: manhattan, weights: uniform, n_neighbors: 5, radius: 131, score: 47.61394505710338
#
# metric: manhattan, weights: uniform, n_neighbors: 5, radius: 132, score: 47.61394505710338
#
# metric: manhattan, weights: uniform, n_neighbors: 5, radius: 133, score: 47.61166905765212
#
# metric: manhattan, weights: uniform, n_neighbors: 5, radius: 134, score: 47.61166905765212
#
# metric: manhattan, weights: uniform, n_neighbors: 5, radius: 135, score: 47.60884783227559
#
# metric: manhattan, weights: uniform, n_neighbors: 5, radius: 136, score: 47.60884783227559
#
# metric: manhattan, weights: uniform, n_neighbors: 5, radius: 137, score: 47.60884783227559
#
# metric: manhattan, weights: uniform, n_neighbors: 5, radius: 138, score: 47.62169513612655
#
# metric: manhattan, weights: uniform, n_neighbors: 5, radius: 139, score: 47.63527956991054
#
# metric: manhattan, weights: uniform, n_neighbors: 5, radius: 140, score: 47.63527956991054
#
# metric: manhattan, weights: uniform, n_neighbors: 5, radius: 141, score: 47.63527956991054
#
# metric: manhattan, weights: uniform, n_neighbors: 5, radius: 142, score: 47.63651512877882
#
# metric: manhattan, weights: uniform, n_neighbors: 5, radius: 143, score: 47.629999585884754
#
# metric: manhattan, weights: uniform, n_neighbors: 5, radius: 144, score: 47.629999585884754
#
# metric: manhattan, weights: uniform, n_neighbors: 5, radius: 145, score: 47.629999585884754
#
# metric: manhattan, weights: uniform, n_neighbors: 5, radius: 146, score: 47.63950621495068
#
# metric: manhattan, weights: uniform, n_neighbors: 5, radius: 147, score: 47.65095936823676
#
# metric: manhattan, weights: uniform, n_neighbors: 5, radius: 148, score: 47.65095936823676
#
# metric: manhattan, weights: uniform, n_neighbors: 5, radius: 149, score: 47.65095936823676
#
# metric: manhattan, weights: uniform, n_neighbors: 5, radius: 150, score: 47.62690930506623
#
# metric: manhattan, weights: uniform, n_neighbors: 5, radius: 151, score: 47.661767868796645
#
# metric: manhattan, weights: uniform, n_neighbors: 5, radius: 152, score: 47.661767868796645
#
# metric: manhattan, weights: uniform, n_neighbors: 5, radius: 153, score: 47.669470835855336
#
# metric: manhattan, weights: uniform, n_neighbors: 5, radius: 154, score: 47.669470835855336
#
# metric: manhattan, weights: uniform, n_neighbors: 5, radius: 155, score: 47.669470835855336
#
# metric: manhattan, weights: uniform, n_neighbors: 5, radius: 156, score: 47.669470835855336
#
# metric: manhattan, weights: uniform, n_neighbors: 5, radius: 157, score: 47.675741615045
#
# metric: manhattan, weights: uniform, n_neighbors: 5, radius: 158, score: 47.675741615045
#
# metric: manhattan, weights: uniform, n_neighbors: 5, radius: 159, score: 47.675741615045
#
# metric: manhattan, weights: uniform, n_neighbors: 5, radius: 160, score: 47.675741615045
#
# metric: manhattan, weights: uniform, n_neighbors: 5, radius: 161, score: 47.675741615045
#
# metric: manhattan, weights: uniform, n_neighbors: 5, radius: 162, score: 47.675741615045
#
# metric: manhattan, weights: uniform, n_neighbors: 5, radius: 163, score: 47.675741615045
#
# metric: manhattan, weights: uniform, n_neighbors: 5, radius: 164, score: 47.675741615045
#
# metric: manhattan, weights: uniform, n_neighbors: 5, radius: 165, score: 47.675741615045
#
# metric: manhattan, weights: uniform, n_neighbors: 5, radius: 166, score: 47.693784393807064
#
# metric: manhattan, weights: uniform, n_neighbors: 5, radius: 167, score: 47.693784393807064
#
# metric: manhattan, weights: uniform, n_neighbors: 5, radius: 168, score: 47.693784393807064
#
# metric: manhattan, weights: uniform, n_neighbors: 5, radius: 169, score: 47.69491275456098
#
# metric: manhattan, weights: uniform, n_neighbors: 5, radius: 170, score: 47.69661089110171
#
# metric: manhattan, weights: uniform, n_neighbors: 5, radius: 171, score: 47.69661089110171
#
# metric: manhattan, weights: uniform, n_neighbors: 5, radius: 172, score: 47.71585557882803
#
# metric: manhattan, weights: uniform, n_neighbors: 5, radius: 173, score: 47.71585557882803
#
# metric: manhattan, weights: uniform, n_neighbors: 5, radius: 174, score: 47.72391262055828
#
# metric: manhattan, weights: uniform, n_neighbors: 5, radius: 175, score: 47.72391262055828
#
# metric: manhattan, weights: uniform, n_neighbors: 5, radius: 176, score: 47.72383454863365
#
# metric: manhattan, weights: uniform, n_neighbors: 5, radius: 177, score: 47.69727641709534
#
# metric: manhattan, weights: uniform, n_neighbors: 5, radius: 178, score: 47.69727641709534
#
# metric: manhattan, weights: uniform, n_neighbors: 5, radius: 179, score: 47.69119829149764
#
# metric: manhattan, weights: uniform, n_neighbors: 5, radius: 180, score: 47.68806157931861
#
# metric: manhattan, weights: uniform, n_neighbors: 5, radius: 181, score: 47.69070836036351
#
# metric: manhattan, weights: uniform, n_neighbors: 5, radius: 182, score: 47.69070836036351
#
# metric: manhattan, weights: uniform, n_neighbors: 5, radius: 183, score: 47.69070836036351
#
# metric: manhattan, weights: uniform, n_neighbors: 5, radius: 184, score: 47.69925208705202
#
# metric: manhattan, weights: uniform, n_neighbors: 5, radius: 185, score: 47.691861348338534
#
# metric: manhattan, weights: uniform, n_neighbors: 5, radius: 186, score: 47.69025576970965
#
# metric: manhattan, weights: uniform, n_neighbors: 5, radius: 187, score: 47.69025576970965
#
# metric: manhattan, weights: uniform, n_neighbors: 5, radius: 188, score: 47.7145758277342
#
# metric: manhattan, weights: uniform, n_neighbors: 5, radius: 189, score: 47.712267900376595
#
# metric: manhattan, weights: uniform, n_neighbors: 5, radius: 190, score: 47.703159405068355
#
# metric: manhattan, weights: uniform, n_neighbors: 5, radius: 191, score: 47.703159405068355
#
# metric: manhattan, weights: uniform, n_neighbors: 5, radius: 192, score: 47.67068084478616
#
# metric: manhattan, weights: uniform, n_neighbors: 5, radius: 193, score: 47.64169217035849
#
# metric: manhattan, weights: uniform, n_neighbors: 5, radius: 194, score: 47.64801387091377
#
# metric: manhattan, weights: uniform, n_neighbors: 5, radius: 195, score: 47.64971258101849
#
# metric: manhattan, weights: uniform, n_neighbors: 5, radius: 196, score: 47.6829524774039
#
# metric: manhattan, weights: uniform, n_neighbors: 5, radius: 197, score: 47.7058745381967
#
# metric: manhattan, weights: uniform, n_neighbors: 5, radius: 198, score: 47.706734028726466
#
# metric: manhattan, weights: uniform, n_neighbors: 5, radius: 199, score: 47.68480949489607
# {'metric': 'euclidean', 'weights': 'uniform', 'n_neighbors': 3, 'radius': 175}

# %%
kradius_model = kradius(**best_params)
kradius_model.fit(X, y)

pred = kradius_model.predict(X_valid)

score = calculate_distance(y_valid, pred)

pred_lon = pred[:, 0]
pred_lat = pred[:, 1]
pred_floor = pred[:, 2]

lon_diff2 = (pred_lon - y_valid_lon) ** 2
lat_diff2 = (pred_lat - y_valid_lat) ** 2
# lets assume that the height of the floors is 5 meters
floor_diff2 = ((pred_floor - y_valid_floor) * 5) ** 2

distance_squared = lon_diff2 + lat_diff2 + floor_diff2

distance = distance_squared.apply(lambda x: x ** (1 / 2))

predictions = pd.DataFrame(
    {
        "LATITUDE": pred_lat,
        "LONGITUDE": pred_lon,
        "FLOOR": pred_floor,
        "distance": distance,
    }
)

true_values = pd.DataFrame(
    {
        "LATITUDE": y_valid_lat,
        "LONGITUDE": y_valid_lon,
        "FLOOR": y_valid_floor,
        "distance": distance,
    }
)
# Out:
# kradius(metric='euclidean', n_jobs=1, n_neighbors=3, radius=175,
#         weights='uniform')

# %%
print(f"Mean error in meters {score}")

for floor in sorted(predictions.FLOOR.unique()):
    fig, ax = plt.subplots()
    sns.scatterplot(
        x="LONGITUDE",
        y="LATITUDE",
        hue="distance",
        ax=ax,
        s=100,
        data=predictions[predictions["FLOOR"] == int(floor)],
    )
    ax.set_aspect(aspect="equal")
    plt.title(f"Predictions Floor {int(floor)}")
    plt.show()

    fig, ax = plt.subplots()
    sns.scatterplot(
        x="LONGITUDE",
        y="LATITUDE",
        hue="distance",
        s=100,
        data=true_values[true_values["FLOOR"] == int(floor)],
        ax=ax,
    )
    ax.set_aspect(aspect="equal")
    plt.title(f"Real Values Floor {int(floor)}")
    plt.show()
# Out:
# Mean error in meters 10.609080375692704
# Text(0.5, 1.0, 'Predictions Floor 0')
# Text(0.5, 1.0, 'Real Values Floor 0')
# Text(0.5, 1.0, 'Predictions Floor 0')
# Text(0.5, 1.0, 'Real Values Floor 0')
# Text(0.5, 1.0, 'Predictions Floor 0')
# Text(0.5, 1.0, 'Real Values Floor 0')
# Text(0.5, 1.0, 'Predictions Floor 0')
# Text(0.5, 1.0, 'Real Values Floor 0')
# Text(0.5, 1.0, 'Predictions Floor 1')
# Text(0.5, 1.0, 'Real Values Floor 1')
# Text(0.5, 1.0, 'Predictions Floor 1')
# Text(0.5, 1.0, 'Real Values Floor 1')
# Text(0.5, 1.0, 'Predictions Floor 1')
# Text(0.5, 1.0, 'Real Values Floor 1')
# Text(0.5, 1.0, 'Predictions Floor 2')
# Text(0.5, 1.0, 'Real Values Floor 2')
# Text(0.5, 1.0, 'Predictions Floor 2')
# Text(0.5, 1.0, 'Real Values Floor 2')
# Text(0.5, 1.0, 'Predictions Floor 2')
# Text(0.5, 1.0, 'Real Values Floor 2')
# Text(0.5, 1.0, 'Predictions Floor 3')
# Text(0.5, 1.0, 'Real Values Floor 3')
# Text(0.5, 1.0, 'Predictions Floor 3')
# Text(0.5, 1.0, 'Real Values Floor 3')
# Text(0.5, 1.0, 'Predictions Floor 4')
# Text(0.5, 1.0, 'Real Values Floor 4')

# %%
predictions.distance.hist(bins=100)
