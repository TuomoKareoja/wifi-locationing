# %%
# Change directory to VSCode workspace root so that relative path loads work correctly. Turn this addition off with the DataScience.changeDirOnImportExport setting
# ms-python.python added
import os
try:
	os.chdir(os.path.join(os.getcwd(), '..'))
	print(os.getcwd())
except:
	pass

# %%
metric_opt = ["manhattan"]
weights_opt = ["uniform", squared_distance]
n_neighbors_opt = [2, 3, 5]
radius_opt = [1, 4, 12, 25]

best_score = None
for n_neighbors in n_neighbors_opt:
    for weights in weights_opt:
        for metric in metric_opt:
            # no need to check for are if just one k
            if n_neighbors == 1:
                radius_opt_modified = [1]
            else:
                radius_opt_modified = radius_opt.copy()

            for radius in radius_opt_modified:
                kradius_model = kradius(
                    metric=metric,
                    weights=weights,
                    n_neighbors=n_neighbors,
                    radius=radius,
                    n_jobs=1,
                )
                folds = KFold(n_splits=8, shuffle=True, random_state=random_state)
                cv_scores = cross_val_score(
                    kradius_model, X, y, scoring=distance_scorer, cv=folds, n_jobs=-2
                )
                score = -np.mean(cv_scores)
                # for train_index, test_index in folds.split(X):
                #     kradius_model = kradius(
                #         metric=metric,
                #         weights=weights,
                #         n_neighbors=n_neighbors,
                #         radius=radius,
                #     )
                #     kradius_model.fit(X.iloc[train_index], y.iloc[train_index])
                #     preds = kradius_model.predict(X.iloc[test_index])
                #     score = calculate_distance(y.iloc[test_index], preds)
                #     scores.append(score)

                # mean_score = np.mean(scores)
                print(
                    f"metric: {metric}, weight: {weights},",
                    f"n_neighbors: {n_neighbors}, radius: {radius},",
                    f"score: {score}",
                )

                if best_score is None or best_score > score:
                    print("new best score found!")
                    best_score = score
                    best_params = {
                        "metric": metric,
                        "weights": weights,
                        "n_neighbors": n_neighbors,
                        "radius": radius,
                    }

                print()


print(best_params)
# Out:
# metric: manhattan, weight: uniform, n_neighbors: 2, radius: 1, score: 3.450677709658966
# new best score found!
#
# metric: manhattan, weight: uniform, n_neighbors: 2, radius: 4, score: 3.4528370832221955
#
# metric: manhattan, weight: uniform, n_neighbors: 2, radius: 12, score: 3.4559458388598516
#
# metric: manhattan, weight: uniform, n_neighbors: 2, radius: 25, score: 3.4931385208814114
#
# metric: manhattan, weight: <function squared_distance at 0x7f149c7e29d8>, n_neighbors: 2, radius: 1, score: 3.455341913503191
#
# metric: manhattan, weight: <function squared_distance at 0x7f149c7e29d8>, n_neighbors: 2, radius: 4, score: 3.4554398539792475
#
# metric: manhattan, weight: <function squared_distance at 0x7f149c7e29d8>, n_neighbors: 2, radius: 12, score: 3.454000731858364
#
# metric: manhattan, weight: <function squared_distance at 0x7f149c7e29d8>, n_neighbors: 2, radius: 25, score: 3.469536836137112
#
# metric: manhattan, weight: uniform, n_neighbors: 3, radius: 1, score: 3.325615971431553
# new best score found!
#
# metric: manhattan, weight: uniform, n_neighbors: 3, radius: 4, score: 3.3302437641712785
#
# metric: manhattan, weight: uniform, n_neighbors: 3, radius: 12, score: 3.339644285717745
#
# metric: manhattan, weight: uniform, n_neighbors: 3, radius: 25, score: 3.372851708599413
#
# metric: manhattan, weight: <function squared_distance at 0x7f149c7e29d8>, n_neighbors: 3, radius: 1, score: 3.331789680284693
#
# metric: manhattan, weight: <function squared_distance at 0x7f149c7e29d8>, n_neighbors: 3, radius: 4, score: 3.332276838950428
#
# metric: manhattan, weight: <function squared_distance at 0x7f149c7e29d8>, n_neighbors: 3, radius: 12, score: 3.332467821299896
#
# metric: manhattan, weight: <function squared_distance at 0x7f149c7e29d8>, n_neighbors: 3, radius: 25, score: 3.350395275778183
#
# metric: manhattan, weight: uniform, n_neighbors: 5, radius: 1, score: 3.292429278709335
# new best score found!
#
# metric: manhattan, weight: uniform, n_neighbors: 5, radius: 4, score: 3.300055980427273
#
# metric: manhattan, weight: uniform, n_neighbors: 5, radius: 12, score: 3.3128655795873074
#
# metric: manhattan, weight: uniform, n_neighbors: 5, radius: 25, score: 3.3675270632027106
#
# metric: manhattan, weight: <function squared_distance at 0x7f149c7e29d8>, n_neighbors: 5, radius: 1, score: 3.2985062625857564
#
# metric: manhattan, weight: <function squared_distance at 0x7f149c7e29d8>, n_neighbors: 5, radius: 4, score: 3.2999255655464386
#
# metric: manhattan, weight: <function squared_distance at 0x7f149c7e29d8>, n_neighbors: 5, radius: 12, score: 3.2998043270056963
#
# metric: manhattan, weight: <function squared_distance at 0x7f149c7e29d8>, n_neighbors: 5, radius: 25, score: 3.3191500249889034
#
# {'metric': 'manhattan', 'weights': 'uniform', 'n_neighbors': 5, 'radius': 1}

# %%
metric_opt = ["manhattan"]
weights_opt = ["uniform", squared_distance]
n_neighbors_opt = [4, 5, 6]
radius_opt = [0.5, 0.8, 1, 1.1, 1.2]

best_score = None
for n_neighbors in n_neighbors_opt:
    for weights in weights_opt:
        for metric in metric_opt:
            # no need to check for are if just one k
            if n_neighbors == 1:
                radius_opt_modified = [1]
            else:
                radius_opt_modified = radius_opt.copy()

            for radius in radius_opt_modified:
                kradius_model = kradius(
                    metric=metric,
                    weights=weights,
                    n_neighbors=n_neighbors,
                    radius=radius,
                    n_jobs=1,
                )
                folds = KFold(n_splits=8, shuffle=True, random_state=random_state)
                cv_scores = cross_val_score(
                    kradius_model, X, y, scoring=distance_scorer, cv=folds, n_jobs=-2
                )
                score = -np.mean(cv_scores)
                print(
                    f"metric: {metric}, weight: {weights},",
                    f"n_neighbors: {n_neighbors}, radius: {radius},",
                    f"score: {score}",
                )

                if best_score is None or best_score > score:
                    print("new best score found!")
                    best_score = score
                    best_params = {
                        "metric": metric,
                        "weights": weights,
                        "n_neighbors": n_neighbors,
                        "radius": radius,
                    }


print(best_params)
# Out:
# metric: manhattan, weight: uniform, n_neighbors: 4, radius: 0.5, score: 3.2892115680300145
# new best score found!
# metric: manhattan, weight: uniform, n_neighbors: 4, radius: 0.8, score: 3.2892115680300145
# metric: manhattan, weight: uniform, n_neighbors: 4, radius: 1, score: 3.2838907845768333
# new best score found!
# metric: manhattan, weight: uniform, n_neighbors: 4, radius: 1.1, score: 3.2838907845768333
# metric: manhattan, weight: uniform, n_neighbors: 4, radius: 1.2, score: 3.2838907845768333
# metric: manhattan, weight: <function squared_distance at 0x7f149c7e29d8>, n_neighbors: 4, radius: 0.5, score: 3.2890155664746006
# metric: manhattan, weight: <function squared_distance at 0x7f149c7e29d8>, n_neighbors: 4, radius: 0.8, score: 3.2890155664746006
# metric: manhattan, weight: <function squared_distance at 0x7f149c7e29d8>, n_neighbors: 4, radius: 1, score: 3.2890155664746006
# metric: manhattan, weight: <function squared_distance at 0x7f149c7e29d8>, n_neighbors: 4, radius: 1.1, score: 3.2890155664746006
# metric: manhattan, weight: <function squared_distance at 0x7f149c7e29d8>, n_neighbors: 4, radius: 1.2, score: 3.2890155664746006
# metric: manhattan, weight: uniform, n_neighbors: 5, radius: 0.5, score: 3.298506262573021
# metric: manhattan, weight: uniform, n_neighbors: 5, radius: 0.8, score: 3.298506262573021
# metric: manhattan, weight: uniform, n_neighbors: 5, radius: 1, score: 3.292429278709335
# metric: manhattan, weight: uniform, n_neighbors: 5, radius: 1.1, score: 3.292429278709335
# metric: manhattan, weight: uniform, n_neighbors: 5, radius: 1.2, score: 3.292429278709335
# metric: manhattan, weight: <function squared_distance at 0x7f149c7e29d8>, n_neighbors: 5, radius: 0.5, score: 3.2985062625857564
# metric: manhattan, weight: <function squared_distance at 0x7f149c7e29d8>, n_neighbors: 5, radius: 0.8, score: 3.2985062625857564
# metric: manhattan, weight: <function squared_distance at 0x7f149c7e29d8>, n_neighbors: 5, radius: 1, score: 3.2985062625857564
# metric: manhattan, weight: <function squared_distance at 0x7f149c7e29d8>, n_neighbors: 5, radius: 1.1, score: 3.2985062625857564
# metric: manhattan, weight: <function squared_distance at 0x7f149c7e29d8>, n_neighbors: 5, radius: 1.2, score: 3.2985062625857564
# metric: manhattan, weight: uniform, n_neighbors: 6, radius: 0.5, score: 3.302621423905213
# metric: manhattan, weight: uniform, n_neighbors: 6, radius: 0.8, score: 3.302621423905213
# metric: manhattan, weight: uniform, n_neighbors: 6, radius: 1, score: 3.2962718175694334
# metric: manhattan, weight: uniform, n_neighbors: 6, radius: 1.1, score: 3.2962718175694334
# metric: manhattan, weight: uniform, n_neighbors: 6, radius: 1.2, score: 3.2962718175694334
# metric: manhattan, weight: <function squared_distance at 0x7f149c7e29d8>, n_neighbors: 6, radius: 0.5, score: 3.303013273447136
# metric: manhattan, weight: <function squared_distance at 0x7f149c7e29d8>, n_neighbors: 6, radius: 0.8, score: 3.303013273447136
# metric: manhattan, weight: <function squared_distance at 0x7f149c7e29d8>, n_neighbors: 6, radius: 1, score: 3.303013273447136
# metric: manhattan, weight: <function squared_distance at 0x7f149c7e29d8>, n_neighbors: 6, radius: 1.1, score: 3.303013273447136
# metric: manhattan, weight: <function squared_distance at 0x7f149c7e29d8>, n_neighbors: 6, radius: 1.2, score: 3.303013273447136
# {'metric': 'manhattan', 'weights': 'uniform', 'n_neighbors': 4, 'radius': 1}

# %%
metric_opt = ["manhattan"]
weights_opt = ["uniform", squared_distance]
n_neighbors_opt = [4]
radius_opt = [1, 2, 3, 4]

best_score = None
for n_neighbors in n_neighbors_opt:
    for weights in weights_opt:
        for metric in metric_opt:
            # no need to check for are if just one k
            if n_neighbors == 1:
                radius_opt_modified = [1]
            else:
                radius_opt_modified = radius_opt.copy()

            for radius in radius_opt_modified:
                kradius_model = kradius(
                    metric=metric,
                    weights=weights,
                    n_neighbors=n_neighbors,
                    radius=radius,
                    n_jobs=1,
                )
                folds = KFold(n_splits=8, shuffle=True, random_state=random_state)
                cv_scores = cross_val_score(
                    kradius_model, X, y, scoring=distance_scorer, cv=folds, n_jobs=-2
                )
                score = -np.mean(cv_scores)
                print(
                    f"metric: {metric}, weight: {weights},",
                    f"n_neighbors: {n_neighbors}, radius: {radius},",
                    f"score: {score}",
                )

                if best_score is None or best_score > score:
                    print("new best score found!")
                    best_score = score
                    best_params = {
                        "metric": metric,
                        "weights": weights,
                        "n_neighbors": n_neighbors,
                        "radius": radius,
                    }


print(best_params)
# Out:
# metric: manhattan, weight: uniform, n_neighbors: 4, radius: 1, score: 3.2838907845768333
# new best score found!
# metric: manhattan, weight: uniform, n_neighbors: 4, radius: 2, score: 3.2831161456392364
# new best score found!
# metric: manhattan, weight: uniform, n_neighbors: 4, radius: 3, score: 3.2836004663438407
# metric: manhattan, weight: uniform, n_neighbors: 4, radius: 4, score: 3.288431328382213
# metric: manhattan, weight: <function squared_distance at 0x7f149c7e29d8>, n_neighbors: 4, radius: 1, score: 3.2890155664746006
# metric: manhattan, weight: <function squared_distance at 0x7f149c7e29d8>, n_neighbors: 4, radius: 2, score: 3.2891033425736484
# metric: manhattan, weight: <function squared_distance at 0x7f149c7e29d8>, n_neighbors: 4, radius: 3, score: 3.289636623121347
# metric: manhattan, weight: <function squared_distance at 0x7f149c7e29d8>, n_neighbors: 4, radius: 4, score: 3.2900140548638173
# {'metric': 'manhattan', 'weights': 'uniform', 'n_neighbors': 4, 'radius': 2}

# %%
metric_opt = ["manhattan"]
weights_opt = ["uniform"]
n_neighbors_opt = [1, 4, 5]
radius_opt = [0.8, 1, 1.2, 1.8, 2, 2.2]

best_score = None
for n_neighbors in n_neighbors_opt:
    for weights in weights_opt:
        for metric in metric_opt:
            # no need to check for are if just one k
            if n_neighbors == 1:
                radius_opt_modified = [1]
            else:
                radius_opt_modified = radius_opt.copy()

            for radius in radius_opt_modified:
                kradius_model = kradius(
                    metric=metric,
                    weights=weights,
                    n_neighbors=n_neighbors,
                    radius=radius,
                    n_jobs=1,
                )
                folds = KFold(n_splits=12, shuffle=True, random_state=random_state)
                cv_scores = cross_val_score(
                    kradius_model, X, y, scoring=distance_scorer, cv=folds, n_jobs=-2
                )
                score = -np.mean(cv_scores)
                print(
                    f"metric: {metric}, weight: {weights},",
                    f"n_neighbors: {n_neighbors}, radius: {radius},",
                    f"score: {score}",
                )

                if best_score is None or best_score > score:
                    print("new best score found!")
                    best_score = score
                    best_params = {
                        "metric": metric,
                        "weights": weights,
                        "n_neighbors": n_neighbors,
                        "radius": radius,
                    }


print(best_params)
# Out:
# metric: manhattan, weight: uniform, n_neighbors: 1, radius: 1, score: 4.054806318230915
# new best score found!
# metric: manhattan, weight: uniform, n_neighbors: 4, radius: 0.8, score: 3.1905426097315748
# new best score found!
# metric: manhattan, weight: uniform, n_neighbors: 4, radius: 1, score: 3.183907337960532
# new best score found!
# metric: manhattan, weight: uniform, n_neighbors: 4, radius: 1.2, score: 3.183907337960532
# metric: manhattan, weight: uniform, n_neighbors: 4, radius: 1.8, score: 3.183907337960532
# metric: manhattan, weight: uniform, n_neighbors: 4, radius: 2, score: 3.1838896320592958
# new best score found!
# metric: manhattan, weight: uniform, n_neighbors: 4, radius: 2.2, score: 3.1838896320592958
# metric: manhattan, weight: uniform, n_neighbors: 5, radius: 0.8, score: 3.173274532125678
# new best score found!
# metric: manhattan, weight: uniform, n_neighbors: 5, radius: 1, score: 3.1678169844364077
# new best score found!
# metric: manhattan, weight: uniform, n_neighbors: 5, radius: 1.2, score: 3.1678169844364077
# metric: manhattan, weight: uniform, n_neighbors: 5, radius: 1.8, score: 3.1678169844364077
# metric: manhattan, weight: uniform, n_neighbors: 5, radius: 2, score: 3.169450098830792
# metric: manhattan, weight: uniform, n_neighbors: 5, radius: 2.2, score: 3.169450098830792
# {'metric': 'manhattan', 'weights': 'uniform', 'n_neighbors': 5, 'radius': 1}

# %%
metric_opt = ["manhattan"]
weights_opt = ["uniform"]
n_neighbors_opt = [4, 5]
radius_opt = [0.9, 0.95, 1, 1.05, 1.1]

best_score = None
for n_neighbors in n_neighbors_opt:
    for weights in weights_opt:
        for metric in metric_opt:
            # no need to check for are if just one k
            if n_neighbors == 1:
                radius_opt_modified = [1]
            else:
                radius_opt_modified = radius_opt.copy()

            for radius in radius_opt_modified:
                kradius_model = kradius(
                    metric=metric,
                    weights=weights,
                    n_neighbors=n_neighbors,
                    radius=radius,
                    n_jobs=1,
                )
                folds = KFold(n_splits=20, shuffle=True, random_state=random_state)
                cv_scores = cross_val_score(
                    kradius_model, X, y, scoring=distance_scorer, cv=folds, n_jobs=-2
                )
                score = -np.mean(cv_scores)
                print(
                    f"metric: {metric}, weight: {weights},",
                    f"n_neighbors: {n_neighbors}, radius: {radius},",
                    f"score: {score}",
                )

                if best_score is None or best_score > score:
                    print("new best score found!")
                    best_score = score
                    best_params = {
                        "metric": metric,
                        "weights": weights,
                        "n_neighbors": n_neighbors,
                        "radius": radius,
                    }


print(best_params)
# Out:
# metric: manhattan, weight: uniform, n_neighbors: 4, radius: 0.9, score: 3.191133314600073
# new best score found!
# metric: manhattan, weight: uniform, n_neighbors: 4, radius: 0.95, score: 3.191133314600073
# metric: manhattan, weight: uniform, n_neighbors: 4, radius: 1, score: 3.184137030986749
# new best score found!
# metric: manhattan, weight: uniform, n_neighbors: 4, radius: 1.05, score: 3.184137030986749
# metric: manhattan, weight: uniform, n_neighbors: 4, radius: 1.1, score: 3.184137030986749
# metric: manhattan, weight: uniform, n_neighbors: 5, radius: 0.9, score: 3.151343207530318
# new best score found!
# metric: manhattan, weight: uniform, n_neighbors: 5, radius: 0.95, score: 3.151343207530318
# metric: manhattan, weight: uniform, n_neighbors: 5, radius: 1, score: 3.1460618422928177
# new best score found!
# metric: manhattan, weight: uniform, n_neighbors: 5, radius: 1.05, score: 3.1460618422928177
# metric: manhattan, weight: uniform, n_neighbors: 5, radius: 1.1, score: 3.1460618422928177
# {'metric': 'manhattan', 'weights': 'uniform', 'n_neighbors': 5, 'radius': 1}

# %%
metric_opt = ["manhattan"]
weights_opt = ["uniform", "distance", squared_distance]
n_neighbors_opt = [1, 2, 3, 5]

best_score_simple_knn = None
for n_neighbors in n_neighbors_opt:
    # no need to check different weights if k = 1
    if n_neighbors == 1:
        weights_opt_modified = ["uniform"]
    else:
        weights_opt_modified = weights_opt.copy()
    for weights in weights_opt_modified:
        for metric in metric_opt:
            knn_model = KNeighborsRegressor(
                metric=metric, weights=weights, n_neighbors=n_neighbors, n_jobs=1
            )
            folds = KFold(n_splits=20, shuffle=True, random_state=random_state)
            cv_scores = cross_val_score(
                knn_model, X, y, scoring=distance_scorer, cv=folds, n_jobs=-2
            )
            score = -np.mean(cv_scores)
            print(
                f"metric: {metric}, weight: {weights},",
                f"n_neighbors: {n_neighbors},",
                f"score: {score}",
            )

            if best_score_simple_knn is None or best_score_simple_knn > score:
                print("new best score found!")
                best_score_simple_knn = score
                best_params_simple_knn = {
                    "metric": metric,
                    "weights": weights,
                    "n_neighbors": n_neighbors,
                }


print(best_params_simple_knn)
# Out:
# metric: manhattan, weight: uniform, n_neighbors: 1, score: 4.032209732726139
# new best score found!
# metric: manhattan, weight: uniform, n_neighbors: 2, score: 3.5853337300067643
# new best score found!
# metric: manhattan, weight: distance, n_neighbors: 2, score: 3.4771216320426404
# new best score found!
# metric: manhattan, weight: <function squared_distance at 0x7f149c7e29d8>, n_neighbors: 2, score: 3.420160520446373
# new best score found!
# metric: manhattan, weight: uniform, n_neighbors: 3, score: 3.7735052213540463
# metric: manhattan, weight: distance, n_neighbors: 3, score: 3.611900635523258
# metric: manhattan, weight: <function squared_distance at 0x7f149c7e29d8>, n_neighbors: 3, score: 3.4984111324318348
# metric: manhattan, weight: uniform, n_neighbors: 5, score: 4.180147144813894
# metric: manhattan, weight: distance, n_neighbors: 5, score: 3.8977246636429492
# metric: manhattan, weight: <function squared_distance at 0x7f149c7e29d8>, n_neighbors: 5, score: 3.678028366545972
# {'metric': 'manhattan', 'weights': <function squared_distance at 0x7f149c7e29d8>, 'n_neighbors': 2}

# %%
best_params
# Out:
# {'metric': 'manhattan', 'weights': 'uniform', 'n_neighbors': 5, 'radius': 1}

# %%
kradius_model = kradius(**best_params)
kradius_model.fit(X, y)
# Out:
# kradius(metric='manhattan', n_jobs=1, n_neighbors=5, radius=1,
#         weights='uniform')

# %%
knn_model = KNeighborsRegressor(**best_params_simple_knn)
knn_model.fit(X, y)
# Out:
# KNeighborsRegressor(algorithm='auto', leaf_size=30, metric='manhattan',
#                     metric_params=None, n_jobs=None, n_neighbors=2, p=2,
#                     weights=<function squared_distance at 0x7f149c7e29d8>)

# %%
kradius_pred = kradius_model.predict(X_comp)
kradius_pred_lon = kradius_pred[:, 0]
kradius_pred_lat = kradius_pred[:, 1]
kradius_pred_floor = np.round(kradius_pred[:, 2], decimals=0)
kradius_pred_building = np.round(kradius_pred[:, 3], decimals=0)

kradius_preds_df = pd.DataFrame(
    {
        "LATITUDE": kradius_pred_lat,
        "LONGITUDE": kradius_pred_lon,
        "FLOOR": kradius_pred_floor,
    }
)

# %%
knn_pred = knn_model.predict(X_comp)
knn_pred_lon = knn_pred[:, 0]
knn_pred_lat = knn_pred[:, 1]
knn_pred_floor = np.round(knn_pred[:, 2], decimals=0)
knn_pred_building = np.round(knn_pred[:, 3], decimals=0)

knn_preds_df = pd.DataFrame(
    {"LATITUDE": knn_pred_lat, "LONGITUDE": knn_pred_lon, "FLOOR": knn_pred_floor}
)

# %%
kradius_preds_df.to_csv(
    os.path.join("data", "predictions", "tuomo_kradius.csv"), index=False
)

knn_preds_df.to_csv(
    os.path.join("data", "predictions", "tuomo_simple_knn.csv"), index=False
)
